# %% [markdown]
# # Linear Discriminant Analysis

# %%
import pandas as pd
train = pd.read_csv('prep_train.csv').filter(items=['Reason for absence', 'Work load Average/day ', 'Disciplinary failure', 'Education', 'Son', 'Weight', 'Height', 'Body mass index', 'Absent'])
train.head(10)
# Out:
#    Reason for absence  Work load Average/day   Disciplinary failure  \
# 0                 1.0                0.194471                   0.0
# 1                 0.0                0.194471                   1.0
# 2                 0.5                0.194471                   0.0
# 3                 1.0                0.194471                   0.0
# 4                 0.5                0.194471                   0.0
# 5                 0.5                0.194471                   0.0
# 6                 1.0                0.194471                   0.0
# 7                 0.5                0.194471                   0.0
# 8                 1.0                0.194471                   0.0
# 9                 1.0                0.194471                   0.0
#
#    Education   Son    Weight    Height  Body mass index  Absent
# 0        0.0  0.50  0.653846  0.272727         0.578947     1.0
# 1        0.0  0.25  0.807692  0.454545         0.631579     0.0
# ...

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

param_grid = {
    'solver'                : ['svd'],
    'store_covariance'      : [True, False],
    'tol'                   : [1e-4, 1e-5, 1e-6, 1e-3, 1e-2]
    
}


X_train, X_test, y_train, y_test = train_test_split(train.drop(['Absent'],axis=1), 
                                                    train['Absent'], test_size=0.30, 
                                                    random_state=1)

grid1 = GridSearchCV(LinearDiscriminantAnalysis(),param_grid,refit=True,verbose=3, scoring='balanced_accuracy')
grid1.fit(X_train,y_train)
# Out:
# /home/random/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] solver=svd, store_covariance=True, tol=0.0001 ...................
# [CV]  solver=svd, store_covariance=True, tol=0.0001, score=0.604, total=   0.0s
# [CV] solver=svd, store_covariance=True, tol=0.0001 ...................
# [CV]  solver=svd, store_covariance=True, tol=0.0001, score=0.588, total=   0.0s
# [CV] solver=svd, store_covariance=True, tol=0.0001 ...................
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop(['Absent'],axis=1), 
                                                    train['Absent'], test_size=0.30, 
                                                    random_state=50)

param_grid = {
    'solver'                : ['lsqr', 'eigen'],
    'shrinkage'             : [None, 'auto']
}





grid2 = GridSearchCV(LinearDiscriminantAnalysis(),param_grid,refit=True,verbose=3, scoring='balanced_accuracy')
grid2.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] shrinkage=None, solver=lsqr .....................................
# [CV] ......... shrinkage=None, solver=lsqr, score=0.655, total=   0.0s
# [CV] shrinkage=None, solver=lsqr .....................................
# [CV] ......... shrinkage=None, solver=lsqr, score=0.649, total=   0.0s
# [CV] shrinkage=None, solver=lsqr .....................................
# [CV] ......... shrinkage=None, solver=lsqr, score=0.560, total=   0.0s
# [CV] shrinkage=None, solver=eigen ....................................
# [CV] ........ shrinkage=None, solver=eigen, score=0.655, total=   0.0s
# [CV] shrinkage=None, solver=eigen ....................................
# [CV] ........ shrinkage=None, solver=eigen, score=0.649, total=   0.0s
# [CV] shrinkage=None, solver=eigen ....................................
# [CV] ........ shrinkage=None, solver=eigen, score=0.560, total=   0.0s
# ...

# %%
print(grid1.best_params_)
predictions = grid1.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print('-----------------------------------')
print(grid2.best_params_)
predictions = grid2.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print('-----------------------------------')
# Out:
# {'solver': 'svd', 'store_covariance': True, 'tol': 0.0001}
# [[ 13  17]
#  [  1 119]]
# 0.88
# -----------------------------------
# {'shrinkage': 'auto', 'solver': 'lsqr'}
# [[ 15  15]
#  [  4 116]]
# 0.8733333333333333
# -----------------------------------
